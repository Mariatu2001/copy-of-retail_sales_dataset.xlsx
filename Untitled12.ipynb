# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariatu2001/copy-of-retail_sales_dataset.xlsx/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SLPTA AI Complaint Classification System
#
# ### Project Objective
#
# This project uses machine learning to automatically classify passenger complaints into categories such as Delay, Safety, Cleanliness, Lost Item, Overcharging, and Other.
#
# The system will analyze complaint text, predict the complaint category, evaluate the model's performance, and provide a simple interface for testing new complaints.
#
# ### Machine Learning Type
# Supervised Learning - Classification

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-765ff88b-057d-4399-8928-2dd6c46fdd39" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-765ff88b-057d-4399-8928-2dd6c46fdd39">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('complaints.csv')

df.head()
# Out:
#   ticket_id         timestamp   channel route_id  \
# 0     C0001  2025-03-14 12:08       SMS       R7
# 1     C0002  2025-03-24 23:20  WhatsApp      R12
# 2     C0003  2025-02-09 02:35  WhatsApp      R12
# 3     C0004  2025-02-22 07:02       SMS       R3
# 4     C0005  2025-02-17 13:40       SMS       R7
#
#                                             raw_text      category severity  \
# 0       R7 never showed at the scheduled time again.         Delay      Low
# 1     Rubbish all over the floor of the R12 vehicle.   Cleanliness     High
# 2  The R12 vehicle had bald tyres and a broken door.        Safety     High
# 3       R3 never showed at the scheduled time again.         Delay   Medium
# 4  Operator OP-103 is collecting extra money and ...  Overcharging      Low
#
#    is_urgent  resolved
# 0      False      True
# 1       True     False
# 2       True      True
# 3      False      True
# 4      False     False

# %%
df = pd.read_csv('complaints.csv')

# %%
print(df.columns.tolist())
# Out:
# ['ticket_id', 'timestamp', 'channel', 'route_id', 'raw_text', 'category', 'severity', 'is_urgent', 'resolved']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ticket_id  400 non-null    object
#  1   timestamp  400 non-null    object
#  2   channel    400 non-null    object
#  3   route_id   400 non-null    object
#  4   raw_text   400 non-null    object
#  5   category   400 non-null    object
#  6   severity   400 non-null    object
#  7   is_urgent  400 non-null    bool
#  8   resolved   400 non-null    bool
# dtypes: bool(2), object(7)
# memory usage: 22.8+ KB

# %%
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# ticket_id    0
# timestamp    0
# channel      0
# route_id     0
# raw_text     0
# category     0
# severity     0
# is_urgent    0
# resolved     0
# dtype: int64

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
df.dtypes
# Out:
# ticket_id    object
# timestamp    object
# channel      object
# route_id     object
# raw_text     object
# category     object
# severity     object
# is_urgent      bool
# resolved       bool
# dtype: object

# %%
df.describe(include='all')
# Out:
#        ticket_id         timestamp channel route_id  \
# count        400               400     400      400
# unique       400               400       4        6
# top        C0384  2025-03-05 13:44     SMS      R12
# freq           1                 1     159      114
#
#                                              raw_text category severity  \
# count                                             400      400      400
# unique                                            170        7        3
# top     R12 never showed at the scheduled time again.    Delay   Medium
# freq                                               14      109      149
#
#        is_urgent resolved
# count        400      400
# unique         2        2
# top        False     True
# freq         254      222

# %%
category_counts = df['category'].value_counts()

print(category_counts)
# Out:
# category
# Delay            109
# Staff Conduct     65
# Safety            63
# Overcharging      48
# Lost Item         44
# Cleanliness       39
# Other             32
# Name: count, dtype: int64

# %%
category_percentages = (
    df['category']
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

print(category_percentages)
# Out:
# category
# Delay            27.25
# Staff Conduct    16.25
# Safety           15.75
# Overcharging     12.00
# Lost Item        11.00
# Cleanliness       9.75
# Other             8.00
# Name: proportion, dtype: float64

# %%
category_counts.plot(kind='bar')

plt.title('Number of Complaints by Category')
plt.xlabel('Complaint Category')
plt.ylabel('Number of Complaints')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
print(df['channel'].value_counts())
# Out:
# channel
# SMS         159
# Call        120
# WhatsApp     86
# InPerson     35
# Name: count, dtype: int64

# %%
df['channel'].value_counts().plot(kind='bar')

plt.title('Complaints by Communication Channel')
plt.xlabel('Communication Channel')
plt.ylabel('Number of Complaints')

plt.tight_layout()
plt.show()

# %%
print(df['severity'].value_counts())
# Out:
# severity
# Medium    149
# Low       146
# High      105
# Name: count, dtype: int64

# %%
print(df['is_urgent'].value_counts())
# Out:
# is_urgent
# False    254
# True     146
# Name: count, dtype: int64

# %%
df['is_urgent'].value_counts().plot(kind='bar')

plt.title('Urgent vs Non-Urgent Complaints')
plt.xlabel('Urgency')
plt.ylabel('Number of Complaints')

plt.tight_layout()
plt.show()

# %%
print(df['resolved'].value_counts())
# Out:
# resolved
# True     222
# False    178
# Name: count, dtype: int64

# %%
df['resolved'].value_counts().plot(kind='bar')

plt.title('Resolved vs Unresolved Complaints')
plt.xlabel('Resolution Status')
plt.ylabel('Number of Complaints')

plt.tight_layout()
plt.show()

# %%
route_counts = df['route_id'].value_counts()

print(route_counts)
# Out:
# route_id
# R12    114
# R7      74
# R9      70
# R14     51
# R3      46
# R21     45
# Name: count, dtype: int64

# %%
df['route_id'].value_counts().head(10).plot(kind='bar')

plt.title('Top 10 Routes by Number of Complaints')
plt.xlabel('Route')
plt.ylabel('Number of Complaints')

plt.tight_layout()
plt.show()

# %%
df[['raw_text', 'category']].head(20)
# Out:
#                                              raw_text       category
# 0        R7 never showed at the scheduled time again.          Delay
# 1      Rubbish all over the floor of the R12 vehicle.    Cleanliness
# 2   The R12 vehicle had bald tyres and a broken door.         Safety
# 3        R3 never showed at the scheduled time again.          Delay
# 4   Operator OP-103 is collecting extra money and ...   Overcharging
# 5   I left my phone on the R14 bus this afternoon,...      Lost Item
# 6           Is R12 running during the public holiday?          Other
# 7            Is R9 running during the public holiday?          Other
# 8   Conductor on R3 charged me 2026 Le above the p...   Overcharging
# 9   Conductor on R3 was rude and shouting at an el...  Staff Conduct
# 10  Driver on R12 was speeding and overtaking dang...         Safety
# 11  Conductor on R9 charged me 2505 Le above the p...   Overcharging
# 12  Why did I pay 2692 Le when the board says the ...   Overcharging
# ...

# %%
category_urgency = pd.crosstab(
    df['category'],
    df['is_urgent']
)

category_urgency
# Out:
# is_urgent      False  True
# category
# Cleanliness       34      5
# Delay             96     13
# Lost Item          0     44
# Other             27      5
# Overcharging      42      6
# Safety             0     63
# Staff Conduct     55     10

# %%
category_urgency.plot(kind='bar')

plt.title('Complaint Category vs Urgency')
plt.xlabel('Complaint Category')
plt.ylabel('Number of Complaints')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
data = df.copy()

# %%
data['raw_text'] = (
    data['raw_text']
    .astype(str)
    .str.strip()
)

# %%
data[['raw_text', 'category']].head()
# Out:
#                                             raw_text      category
# 0       R7 never showed at the scheduled time again.         Delay
# 1     Rubbish all over the floor of the R12 vehicle.   Cleanliness
# 2  The R12 vehicle had bald tyres and a broken door.        Safety
# 3       R3 never showed at the scheduled time again.         Delay
# 4  Operator OP-103 is collecting extra money and ...  Overcharging

# %%
data = data[data['raw_text'].str.len() > 0]

print("Number of records after cleaning:", len(data))
# Out:
# Number of records after cleaning: 400

# %%
X = data['raw_text']
y = data['category']

print("Input variable: raw_text")
print("Target variable: category")
# Out:
# Input variable: raw_text
# Target variable: category

# %%
print(y.value_counts())
# Out:
# category
# Delay            109
# Staff Conduct     65
# Safety            63
# Overcharging      48
# Lost Item         44
# Cleanliness       39
# Other             32
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training records:", len(X_train))
print("Testing records:", len(X_test))
# Out:
# Training records: 320
# Testing records: 80

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(
    lowercase=True,
    stop_words='english',
    ngram_range=(1, 2)
)

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

print("TF-IDF transformation completed.")
print("Training matrix shape:", X_train_tfidf.shape)
print("Testing matrix shape:", X_test_tfidf.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_514/3199679495.py in <cell line: 0>()
# ----> 1 vectorizer = TfidfVectorizer(
#       2     lowercase=True,
#       3     stop_words='english',
#       4     ngram_range=(1, 2)
#       5 )
#
# NameError: name 'TfidfVectorizer' is not defined

# %%
model = LogisticRegression(
    max_iter=1000,
    random_state=42
)

model.fit(X_train_tfidf, y_train)

print("Model training completed!")
